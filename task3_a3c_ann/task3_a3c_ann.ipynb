# %%
# Reload all modules (except those excluded by %aimport) every time before executing the Python code typed.
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
import sys
sys.path.append("../")
import os
import collections
import numpy as np
import matplotlib.pyplot as plt
# from task1_environment.environment.main import PacMan
from matplotlib.animation import FuncAnimation
from IPython.display import HTML

import argparse
import torch
import torch.multiprocessing as mp

from task3_a3c_ann.Worker import Net
from task2_qlearning_junru_xiong.main import PacManJX
from task3_a3c_ann.a3c_policy import A3C_Policy_test
from task3_a3c_ann.utils import v_wrap, set_init, push_and_pull

# %% [markdown]
# ## Baseline

# %%
game0 = PacManJX(maze_row_num=2, maze_column_num=2, maze_row_height=2, maze_column_width=2)
game0.random_reset()
game0.generate_animation()
ani0 = HTML(game0.animation.to_jshtml())
ani0
# Out:
# Generated frames: 178
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
# ...

# %% [markdown]
# ## Test A3C model

# %%
model = Net(s_dim=15, a_dim=4)
state = torch.load(r'D:\OneDrive_CIty\OneDrive - City, University of London\cityU\INM707_Deep reinforcement learning\git\2final_submission\Deep-Reinforcement-Learinng-Submission\task3_a3c_ann\saved_models\a3c_ann_h4w4_intelGhost_lr1e-4_gamma0.9_300kIteration.pt')
model.load_state_dict(state['model_state_dict'])
# Out:
# <All keys matched successfully>

# %%
game = PacManJX(maze_row_num=2, maze_column_num=2, maze_row_height=4, maze_column_width=4)
game.blinky_random = False
game.agent.net = model
game.policy = A3C_Policy_test
game.random_reset()
game.generate_animation()
ani = HTML(game.animation.to_jshtml())
ani
# Out:
# Generated frames: 59
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
# ...

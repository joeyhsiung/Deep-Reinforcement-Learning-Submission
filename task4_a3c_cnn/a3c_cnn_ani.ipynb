# %%
# Reload all modules (except those excluded by %aimport) every time before executing the Python code typed.
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
import os
import collections
import matplotlib.pyplot as plt
from environment.main import PacMan
from matplotlib.animation import FuncAnimation
from IPython.display import HTML
# from a3c_cnn.main import a3c_demo

import argparse
import os
import torch
import torch.multiprocessing as mp

# from a3c_cnn.optimisation import SharedAdam
# from a3c_cnn.model import ActorCritic
# from a3c_cnn.test import test
# from a3c_cnn.train import train
# from a3c_cnn.policy import A3CPolicy
from environment.main import PacMan

from a3c2 import Net
from a3ctwo.policy import A3CTwo
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
game = PacMan(maze_row_num=2, maze_column_num=2, maze_row_height=2, maze_column_width=2)
game.random_reset()
game.generate_animation()
ani = HTML(game.animation.to_jshtml())
ani
# Out:
# Generated frames: 192
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Mircosoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_img65c1ac90d5df44a2a27f180111230530">
#   <div class="anim-controls">
#     <input id="_anim_slider65c1ac90d5df44a2a27f180111230530" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="anim65c1ac90d5df44a2a27f180111230530.set_frame(parseInt(this.value));"></input>
#     <div class="anim-buttons">
#       <button title="Decrease speed" onclick="anim65c1ac90d5df44a2a27f180111230530.slower()">
#           <i class="fa fa-minus"></i></button>
#       <button title="First frame" onclick="anim65c1ac90d5df44a2a27f180111230530.first_frame()">
#         <i class="fa fa-fast-backward"></i></button>
#       <button title="Previous frame" onclick="anim65c1ac90d5df44a2a27f180111230530.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button title="Play backwards" onclick="anim65c1ac90d5df44a2a27f180111230530.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button title="Pause" onclick="anim65c1ac90d5df44a2a27f180111230530.pause_animation()">
#           <i class="fa fa-pause"></i></button>
#       <button title="Play" onclick="anim65c1ac90d5df44a2a27f180111230530.play_animation()">
#           <i class="fa fa-play"></i></button>
#       <button title="Next frame" onclick="anim65c1ac90d5df44a2a27f180111230530.next_frame()">
#           <i class="fa fa-step-forward"></i></button>
#       <button title="Last frame" onclick="anim65c1ac90d5df44a2a27f180111230530.last_frame()">
#           <i class="fa fa-fast-forward"></i></button>
#       <button title="Increase speed" onclick="anim65c1ac90d5df44a2a27f180111230530.faster()">
#           <i class="fa fa-plus"></i></button>
#     </div>
#     <form title="Repetition mode" action="#n" name="_anim_loop_select65c1ac90d5df44a2a27f180111230530"
#           class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_65c1ac90d5df44a2a27f180111230530"
#              >
#       <label for="_anim_radio1_65c1ac90d5df44a2a27f180111230530">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_65c1ac90d5df44a2a27f180111230530"
#              checked>
#       <label for="_anim_radio2_65c1ac90d5df44a2a27f180111230530">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_65c1ac90d5df44a2a27f180111230530"
#              >
#       <label for="_anim_radio3_65c1ac90d5df44a2a27f180111230530">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_img65c1ac90d5df44a2a27f180111230530";
#     var slider_id = "_anim_slider65c1ac90d5df44a2a27f180111230530";
#     var loop_select_id = "_anim_loop_select65c1ac90d5df44a2a27f180111230530";
#     var frames = new Array(193);
#
#   frames[0] = "...\
# bGliIHZlcnNpb24zLjMuMiwgaHR0cHM6Ly9tYXRwbG90bGliLm9yZy8vihELAAAACXBIWXMAAAsT\
# AAALEwEAmpwYAAAfJElEQVR4nO3csY1TQRhGUQYeDTgnI6IGQiIiS/RAQgMuwaIVhLRFENEGGYEr\
# sJjtAIkV8n2zPqeCT0+TPOnqH3POFwAAAAAAAAAAdF7WAwAAAAAAAAAA7p2AAwAAAAAAAAAgJuAA\
# AAAAAAAAAIgJOAAAAAAAAAAAYgIOAAAAAAAAAICYgAMAAAAAAAAAICbgAAAAAAAAAACICTgAAAAA\
# AAAAAGICDgAAAAAAAACAmIADAAAAA

# %%
model = Net(100, 4)
state = torch.load('a3ctwo/1cnn_dropout_0.2_channel_4.pt')
model.load_state_dict(state['model_state_dict'])
game = PacMan(maze_row_num=2, maze_column_num=2, maze_row_height=2, maze_column_width=2)
policy = A3CTwo(model)
game.agent.set_policy(policy)
game.random_reset()
game.generate_animation()
ani = HTML(game.animation.to_jshtml())
ani
# Out:
# Generated frames: 11
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Mircosoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_imgb3b79d95f24c410b848e4e72e80acefd">
#   <div class="anim-controls">
#     <input id="_anim_sliderb3b79d95f24c410b848e4e72e80acefd" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="animb3b79d95f24c410b848e4e72e80acefd.set_frame(parseInt(this.value));"></input>
#     <div class="anim-buttons">
#       <button title="Decrease speed" onclick="animb3b79d95f24c410b848e4e72e80acefd.slower()">
#           <i class="fa fa-minus"></i></button>
#       <button title="First frame" onclick="animb3b79d95f24c410b848e4e72e80acefd.first_frame()">
#         <i class="fa fa-fast-backward"></i></button>
#       <button title="Previous frame" onclick="animb3b79d95f24c410b848e4e72e80acefd.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button title="Play backwards" onclick="animb3b79d95f24c410b848e4e72e80acefd.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button title="Pause" onclick="animb3b79d95f24c410b848e4e72e80acefd.pause_animation()">
#           <i class="fa fa-pause"></i></button>
#       <button title="Play" onclick="animb3b79d95f24c410b848e4e72e80acefd.play_animation()">
#           <i class="fa fa-play"></i></button>
#       <button title="Next frame" onclick="animb3b79d95f24c410b848e4e72e80acefd.next_frame()">
#           <i class="fa fa-step-forward"></i></button>
#       <button title="Last frame" onclick="animb3b79d95f24c410b848e4e72e80acefd.last_frame()">
#           <i class="fa fa-fast-forward"></i></button>
#       <button title="Increase speed" onclick="animb3b79d95f24c410b848e4e72e80acefd.faster()">
#           <i class="fa fa-plus"></i></button>
#     </div>
#     <form title="Repetition mode" action="#n" name="_anim_loop_selectb3b79d95f24c410b848e4e72e80acefd"
#           class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_b3b79d95f24c410b848e4e72e80acefd"
#              >
#       <label for="_anim_radio1_b3b79d95f24c410b848e4e72e80acefd">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_b3b79d95f24c410b848e4e72e80acefd"
#              checked>
#       <label for="_anim_radio2_b3b79d95f24c410b848e4e72e80acefd">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_b3b79d95f24c410b848e4e72e80acefd"
#              >
#       <label for="_anim_radio3_b3b79d95f24c410b848e4e72e80acefd">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_imgb3b79d95f24c410b848e4e72e80acefd";
#     var slider_id = "_anim_sliderb3b79d95f24c410b848e4e72e80acefd";
#     var loop_select_id = "_anim_loop_selectb3b79d95f24c410b848e4e72e80acefd";
#     var frames = new Array(12);
#
#   frames[0] = "...\
# bGliIHZlcnNpb24zLjMuMiwgaHR0cHM6Ly9tYXRwbG90bGliLm9yZy8vihELAAAACXBIWXMAAAsT\
# AAALEwEAmpwYAAAfH0lEQVR4nO3csY1TQRhGUQ96FTjYUoiogMgS2lbQlmCR04cjoq2AAmiA3A1g\
# NNTAauXrsc+p4NPTS0a6+seccwcAAAAAAAAAQOdDPQAAAAAAAAAA4NEJOAAAAAAAAAAAYgIOAAAA\
# AAAAAICYgAMAAAAAAAAAICbgAAAAAAAAAACICTgAAAAAAAAAAGICDgAAAAAAAACAmIADAAAAAAAA\
# ACAm4AAAAAAAAAAAiAk4AAAAAAAAAA

# %%
from tqdm import tqdm
win = 0 
for i in tqdm(range(100)):
    game.random_reset()
    while not game.process.termination:
        game.run_one_step_without_graph()
    if game.process.win:
        win+=1
print(win)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 100/100 [00:01<00:00, 70.76it/s]
# 0

# %%
model = ActorCritic()
checkpoint = torch.load('a3c_model_checkpoint')
model.load_state_dict(checkpoint['model_state_dict'])
game = PacMan(maze_row_num=2, maze_column_num=2, maze_row_height=2, maze_column_width=2)
policy = A3CPolicy(model)
game.agent.set_policy(policy)
game.random_reset()
game.generate_animation()
ani = HTML(game.animation.to_jshtml())
ani
# Out:
# Generated frames: 0tensor([[0.2473, 0.2464, 0.2458, 0.2604]], grad_fn=<SoftmaxBackward>)
# 3 (0, -1)
# tensor([[-0.0034, -0.0068, -0.0093,  0.0485]], grad_fn=<AddmmBackward>)
# Generated frames: 1tensor([[0.2505, 0.2488, 0.2472, 0.2536]], grad_fn=<SoftmaxBackward>)
# 3 (0, -1)
# tensor([[ 0.0120,  0.0054, -0.0010,  0.0244]], grad_fn=<AddmmBackward>)
# Generated frames: 2tensor([[0.2484, 0.2464, 0.2506, 0.2546]], grad_fn=<SoftmaxBackward>)
# 3 (0, -1)
# tensor([[-0.0038, -0.0118,  0.0049,  0.0209]], grad_fn=<AddmmBackward>)
# Generated frames: 3tensor([[0.2443, 0.2492, 0.2533, 0.2533]], grad_fn=<SoftmaxBackward>)
# 3 (0, -1)
# tensor([[-0.0238, -0.0040,  0.0122,  0.0123]], grad_fn=<AddmmBackward>)
# Generated frames: 4tensor([[0.2388, 0.2518, 0.2517, 0.2577]], grad_fn=<SoftmaxBackward>)
# 3 (0, -1)
# tensor([[-0.0364,  0.0164,  0.0160,  0.0395]], grad_fn=<AddmmBackward>)
# Generated frames: 5tensor([[0.2457, 0.2489, 0.2515, 0.2539]], grad_fn=<SoftmaxBackward>)
# 3 (0, -1)
# tensor([[-0.0176, -0.0049,  0.0054,  0.0152]], grad_fn=<AddmmBackward>)
# Generated frames: 6tensor([[0.2463, 0.2463, 0.2492, 0.2582]], grad_fn=<SoftmaxBackward>)
# 3 (0, -1)
# tensor([[-1.1571e-02, -1.1470e-02, -7.4005e-05,  3.5513e-02]],
#        grad_fn=<AddmmBackward>)
# Generated frames: 7
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Mircosoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_imgcf07988769d44ac1bd4640cbead96ed9">
#   <div class="anim-controls">
#     <input id="_anim_slidercf07988769d44ac1bd4640cbead96ed9" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="animcf07988769d44ac1bd4640cbead96ed9.set_frame(parseInt(this.value));"></input>
#     <div class="anim-buttons">
#       <button title="Decrease speed" onclick="animcf07988769d44ac1bd4640cbead96ed9.slower()">
#           <i class="fa fa-minus"></i></button>
#       <button title="First frame" onclick="animcf07988769d44ac1bd4640cbead96ed9.first_frame()">
#         <i class="fa fa-fast-backward"></i></button>
#       <button title="Previous frame" onclick="animcf07988769d44ac1bd4640cbead96ed9.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button title="Play backwards" onclick="animcf07988769d44ac1bd4640cbead96ed9.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button title="Pause" onclick="animcf07988769d44ac1bd4640cbead96ed9.pause_animation()">
#           <i class="fa fa-pause"></i></button>
#       <button title="Play" onclick="animcf07988769d44ac1bd4640cbead96ed9.play_animation()">
#           <i class="fa fa-play"></i></button>
#       <button title="Next frame" onclick="animcf07988769d44ac1bd4640cbead96ed9.next_frame()">
#           <i class="fa fa-step-forward"></i></button>
#       <button title="Last frame" onclick="animcf07988769d44ac1bd4640cbead96ed9.last_frame()">
#           <i class="fa fa-fast-forward"></i></button>
#       <button title="Increase speed" onclick="animcf07988769d44ac1bd4640cbead96ed9.faster()">
#           <i class="fa fa-plus"></i></button>
#     </div>
#     <form title="Repetition mode" action="#n" name="_anim_loop_selectcf07988769d44ac1bd4640cbead96ed9"
#           class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_cf07988769d44ac1bd4640cbead96ed9"
#              >
#       <label for="_anim_radio1_cf07988769d44ac1bd4640cbead96ed9">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_cf07988769d44ac1bd4640cbead96ed9"
#              checked>
#       <label for="_anim_radio2_cf07988769d44ac1bd4640cbead96ed9">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_cf07988769d44ac1bd4640cbead96ed9"
#              >
#       <label for="_anim_radio3_cf07988769d44ac1bd4640cbead96ed9">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_imgcf07988769d44ac1bd4640cbead96ed9";
#     var slider_id = "_anim_slidercf07988769d44ac1bd4640cbead96ed9";
#     var loop_select_id = "_anim_loop_selectcf07988769d44ac1bd4640cbead96ed9";
#     var frames = new Array(8);
#
#   frames[0] = "...\
# bGliIHZlcnNpb24zLjMuMiwgaHR0cHM6Ly9tYXRwbG90bGliLm9yZy8vihELAAAACXBIWXMAAAsT\
# AAALEwEAmpwYAAAfBklEQVR4nO3csY0TURhGUQ8aGpiACihjwy1gJEQL1DAluIHNyVdILoBuyAhc\
# wYpHB0gke/3scyr4gpc86epfxhgnAAAAAAAAAAA6H+oBAAAAAAAAAACPTsABAAAAAAAAABATcAAA\
# AAAAAAAAxAQcAAAAAAAAAAAxAQcAAAAAAAAAQEzAAQAAAAAAAAAQE3AAAAAAAAAAAMQEHAAAAAAA\
# AAAAMQEHAAAAAAAAAEBMwAEAAAAAAAA

# %%
print(game.agent.policy.model == model)
# Out:
# True

# %%
test = ActorCritic()

# %%
test.eval()
# Out:
# ActorCritic(
#   (conv1): Conv2d(1, 2, kernel_size=(2, 2), stride=(1, 1))
#   (conv2): Conv2d(2, 2, kernel_size=(2, 2), stride=(1, 1))
#   (critic_linear): Linear(in_features=50, out_features=1, bias=True)
#   (actor_linear): Linear(in_features=50, out_features=4, bias=True)
# )

# %%
test((torch.rand(1,1,7,7),(1,1)))
# Out:
# (tensor([[0.5338]], grad_fn=<AddmmBackward>),
#  tensor([[0.0067, 0.0088, 0.0096, 0.0055]], grad_fn=<AddmmBackward>),
#  (1, 1))

# %%
test((torch.from_numpy(game.synthetic_array).unsqueeze(0).unsqueeze(0).float(),(1,1)))

# %%
# Reload all modules (except those excluded by %aimport) every time before executing the Python code typed.
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
import os
import collections
import matplotlib.pyplot as plt
from environment.main import PacMan
from matplotlib.animation import FuncAnimation
from IPython.display import HTML
# from a3c_cnn.main import a3c_demo

import argparse
import os
import torch
import torch.multiprocessing as mp

from a3c_cnn.optimisation import SharedAdam
from a3c_cnn.model import ActorCritic
from a3c_cnn.test import test
from a3c_cnn.train import train
from a3c_cnn.policy import A3CPolicy
from environment.main import PacMan

from a3c2 import Net
from a3ctwo.policy import A3CTwo
model = Net(144, 4)
model.eval()
checkpoint = torch.load('a3c2_model_checkpoint_with_3cnn')
model.load_state_dict(checkpoint['model_state_dict'])
game = PacMan(maze_row_num=2, maze_column_num=2, maze_row_height=2, maze_column_width=2)
policy = A3CTwo(model)
game.agent.set_policy(policy)
game.random_reset()
game.generate_animation()
ani = HTML(game.animation.to_jshtml())
print('\n',game.process.reward)
ani
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# Generated frames: 0
#  0
# Generated frames: 1
#  2
# Generated frames: 2
#  0
# Generated frames: 3
#  2
# Generated frames: 4
#  5
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Mircosoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_imgde4a484af7eb4bddaa9a18a8c9e3e8a5">
#   <div class="anim-controls">
#     <input id="_anim_sliderde4a484af7eb4bddaa9a18a8c9e3e8a5" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="animde4a484af7eb4bddaa9a18a8c9e3e8a5.set_frame(parseInt(this.value));"></input>
#     <div class="anim-buttons">
#       <button title="Decrease speed" onclick="animde4a484af7eb4bddaa9a18a8c9e3e8a5.slower()">
#           <i class="fa fa-minus"></i></button>
#       <button title="First frame" onclick="animde4a484af7eb4bddaa9a18a8c9e3e8a5.first_frame()">
#         <i class="fa fa-fast-backward"></i></button>
#       <button title="Previous frame" onclick="animde4a484af7eb4bddaa9a18a8c9e3e8a5.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button title="Play backwards" onclick="animde4a484af7eb4bddaa9a18a8c9e3e8a5.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button title="Pause" onclick="animde4a484af7eb4bddaa9a18a8c9e3e8a5.pause_animation()">
#           <i class="fa fa-pause"></i></button>
#       <button title="Play" onclick="animde4a484af7eb4bddaa9a18a8c9e3e8a5.play_animation()">
#           <i class="fa fa-play"></i></button>
#       <button title="Next frame" onclick="animde4a484af7eb4bddaa9a18a8c9e3e8a5.next_frame()">
#           <i class="fa fa-step-forward"></i></button>
#       <button title="Last frame" onclick="animde4a484af7eb4bddaa9a18a8c9e3e8a5.last_frame()">
#           <i class="fa fa-fast-forward"></i></button>
#       <button title="Increase speed" onclick="animde4a484af7eb4bddaa9a18a8c9e3e8a5.faster()">
#           <i class="fa fa-plus"></i></button>
#     </div>
#     <form title="Repetition mode" action="#n" name="_anim_loop_selectde4a484af7eb4bddaa9a18a8c9e3e8a5"
#           class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_de4a484af7eb4bddaa9a18a8c9e3e8a5"
#              >
#       <label for="_anim_radio1_de4a484af7eb4bddaa9a18a8c9e3e8a5">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_de4a484af7eb4bddaa9a18a8c9e3e8a5"
#              checked>
#       <label for="_anim_radio2_de4a484af7eb4bddaa9a18a8c9e3e8a5">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_de4a484af7eb4bddaa9a18a8c9e3e8a5"
#              >
#       <label for="_anim_radio3_de4a484af7eb4bddaa9a18a8c9e3e8a5">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_imgde4a484af7eb4bddaa9a18a8c9e3e8a5";
#     var slider_id = "_anim_sliderde4a484af7eb4bddaa9a18a8c9e3e8a5";
#     var loop_select_id = "_anim_loop_selectde4a484af7eb4bddaa9a18a8c9e3e8a5";
#     var frames = new Array(5);
#
#   frames[0] = "...\
# bGliIHZlcnNpb24zLjMuMiwgaHR0cHM6Ly9tYXRwbG90bGliLm9yZy8vihELAAAACXBIWXMAAAsT\
# AAALEwEAmpwYAAAfDElEQVR4nO3csa0TQRhGURaWBhyQ0QAFEBFSwEqIKsjRluAa6AHJEREhZZCR\
# uwEsDQEdvODdHfucCj6tJlnp6l/GGC8AAAAAAAAAAOi8rAcAAAAAAAAAADw6AQcAAAAAAAAAQEzA\
# AQAAAAAAAAAQE3AAAAAAAAAAAMQEHAAAAAAAAAAAMQEHAAAAAAAAAEBMwAEAAAAAAAAAEBNwAAAA\
# AAAAAADEBBwAAAAAAAAAADEBBwAAAAA
